# %%
import pygad
import numpy
import pandas as pd

# %%
class ORD:
    def __init__(self, path, deadline_scope, size, tuning_values, filter_value, filter=None, common=None):
        self.deadline_scope = deadline_scope
        self.ordplan = pd.read_csv(path, header=None)
        self.filter = True if filter is None else filter
        self.common = False if common is None else common
        self.size = size
        self.tuning_values = tuning_values
        self.filter_value = filter_value

    def prep(self):
        orders = self.ordplan

        #เอาไซส์กระดาษมาหารกับปริมาณการตัด เช่น กระดาษ 63 ถ้าตัดสองครั้งจได้ ~31 แล้วบันทึกเก็บไว้
        selected_values = self.size / self.tuning_values
        for i, row in orders.iterrows():
            diff = abs(selected_values - row["ตัดกว้าง"])
            orders.loc[i, "diff"] = diff

        #โดยออเดอร์ที่สามารถนำมาคู่กันได้ สำหรับกระดาษไซส์นี้ จะมีขนาดไม่เกิน 31(+-filter value) โดย filter value คือค่าที่กำหนดเอง
        new_orders = orders
        if self.filter:
            new_orders = (
                orders[orders["diff"] < self.filter_value].sort_values(by="ตัดกว้าง").reset_index(drop=True)
            )
        # print(new_orders)

        init_order = new_orders.iloc[0]

        if self.common:
            # Filter based on the first order
            temp = new_orders[new_orders.apply(lambda order: all(init_order[i] == order[i] for i in [3, 4, 5, 6, 7, 8, 12]), axis=1)]
        else:
            temp = new_orders

        return temp

    def get(self):
        ordplan = self.ordplan

        col_to_drop = (
            list(range(9, 12))
            + list(range(13, 14))
            + list(range(15, 18))
            + list(range(19, 26))
        )
        ordplan = ordplan.drop(columns=col_to_drop, axis=1)

        col = [
            "กำหนดส่ง",
            "แผ่นหน้า",
            "ลอน C",
            "แผ่นกลาง",
            "ลอน B",
            "แผ่นหลัง",
            "จำนวนชั้น",
            "ตัดกว้าง",
            "ตัดยาว",
            "เลขที่ใบสั่งขาย",
            "จำนวนสั่งขาย",
            "ประเภททับเส้น",
        ]
        ordplan.columns = col

        new_col = ["เลขที่ใบสั่งขาย"] + [
            col for col in ordplan.columns if col != "เลขที่ใบสั่งขาย"
        ]
        ordplan = ordplan.reindex(columns=new_col)
        ordplan["เลขที่ใบสั่งขาย"] = (
            ordplan["เลขที่ใบสั่งขาย"].astype(str).str.replace("121811", "x")
        )

        ordplan = ordplan[
            (ordplan["ตัดกว้าง"] != 0) & (ordplan["ตัดยาว"] != 0)
        ]  # filter out zero values -> index misaligned

        ordplan["ตัดกว้าง"] = round(ordplan["ตัดกว้าง"] / 25.4, 4)
        ordplan["ตัดยาว"] = round(ordplan["ตัดยาว"] / 25.4, 4)

        ordplan["จำนวนสั่งขาย"] = ordplan["จำนวนสั่งขาย"].str.replace(
            ",", ""
        )  # fix error values ex. 10,00 -> 1000
        ordplan.fillna(0, inplace=True)  # fix error values ex. , -> NA
        ordplan["จำนวนสั่งขาย"] = ordplan["จำนวนสั่งขาย"].astype(int)  # turns str -> int

        if self.deadline_scope >= 0:
            deadline = ordplan["กำหนดส่ง"].iloc[self.deadline_scope]
            ordplan = ordplan[ordplan["กำหนดส่ง"] == deadline]
        ordplan = ordplan.reset_index(drop=True)

        self.ordplan = ordplan

        return self.prep()

    def calculate_trim_and_roll(width):
        roll_paper = [68, 73, 75, 79, 82, 85, 88, 91, 95, 97]
        trim_min = 1
        trim_max = 3
        trim = [paper - width for paper in roll_paper]
        valid_trim_values = [t for t in trim if trim_min <= t <= trim_max]

        if valid_trim_values:
            roll = roll_paper[trim.index(valid_trim_values[0])]
            return valid_trim_values[0], int(roll)
        else:
            return None, None

    def calculate_roll(width):
        roll_paper = [68, 73, 75, 79, 82, 85, 88, 91, 95, 97]
        trim_min = 1
        trim_max = 3
        roll = None
        for i in range(1, 4):
            trim = [paper - width * i for paper in roll_paper]
            valid_trim_values = [t for t in trim if trim_min <= t <= trim_max]

            if valid_trim_values:
                roll = roll_paper[trim.index(valid_trim_values[0])]

        return roll

    def calculate_roll_tuning(width, tuning_values):
        roll_paper = [68, 73, 75, 79, 82, 85, 88, 91, 95, 97]
        trim_min = 1
        trim_max = 3
        roll = None
        trim = [paper - width * tuning_values for paper in roll_paper]
        valid_trim_values = [t for t in trim if trim_min <= t <= trim_max]

        if valid_trim_values:
            roll = roll_paper[trim.index(valid_trim_values[0])]
        return roll

    def calculate_roll_and_width(paper, width):
        trim_min = 1
        trim_max = 3
        if trim_min <= paper - width <= trim_max:
            return False
        return True

    def check_roll_compat(self, var, i, orders, PAPER_SIZE):
        if var:  # ถ้า var = 0 False
            if ORD.calculate_roll_and_width(
                PAPER_SIZE, 2 * orders.loc[i, "ตัดกว้าง"]
            ):  # ถ้า width *2 แล้วผ่าน False
                if ORD.calculate_roll_and_width(
                    PAPER_SIZE, 3 * orders.loc[i, "ตัดกว้าง"]
                ):  # ถ้า width *3 แล้วผ่าน False
                    if ORD.calculate_roll_and_width(
                        PAPER_SIZE, 4 * orders.loc[i, "ตัดกว้าง"]
                    ):  # ถ้า width *4 แล้วผ่าน False
                        if ORD.calculate_roll_and_width(
                            PAPER_SIZE, 5 * orders.loc[i, "ตัดกว้าง"]
                        ):  # ถ้า width *5 แล้วผ่าน False
                            if ORD.calculate_roll_and_width(
                                PAPER_SIZE, 6 * orders.loc[i, "ตัดกว้าง"]
                            ):  # ถ้า width *6 แล้วผ่าน False ex. 4*6 = 24 > 22-24 = -2
                                return abs(PAPER_SIZE * 2)
        return 0

# %%
class GA:
    def __init__(self, orders, size, num_generations, showOutput=None, save_solutions=None, showZero=None):
        self.orders = orders
        self.PAPER_SIZE = size
        self.showOutput = False if showOutput is None else showOutput
        self.save_solutions = False if save_solutions is None else save_solutions
        self.showZero = False if showZero is None else showZero

        self.num_generations = num_generations
        # num_parents_mating = len(orders)
        # self.num_parents_mating = int((orders['จำนวนสั่งขาย'].median()/100 + size/100)/2)
        self.num_parents_mating = 60

        # sol_per_pop = len(orders)*2
        # self.sol_per_pop =  int(orders['จำนวนสั่งขาย'].median()/100 + size/100)
        self.sol_per_pop = 120
        self.num_genes = len(self.orders)

        self.init_range_low = 0
        self.init_range_high = 3
        # self.init_range_high = abs(int(orders['จำนวนสั่งขาย'].median()/100 + size/100 - len(orders)*tuning_parameters))

        self.parent_selection_type = "tournament"
        # rws (for roulette wheel selection)
        # rank (for rank selection)
        # tournament (for tournament selection) - the best
        # sus (chat suggestion, stochastic_universal_selection)

        # crossover_type = "two_points"
        self.crossover_type = "uniform"  # - the best
        # crossover_type = "single_point"

        self.mutation_type = "random"
        self.mutation_percent_genes = 10
        # mutation_type = "adaptive"
        # mutation_percent_genes = (10,20)
        self.gene_type = int

        self.model = pygad.GA(
            num_generations=self.num_generations,
            num_parents_mating=self.num_parents_mating,
            fitness_func=self.fitness_function,
            sol_per_pop=self.sol_per_pop,
            num_genes=self.num_genes,
            parent_selection_type=self.parent_selection_type,
            gene_type=self.gene_type,
            init_range_low=self.init_range_low,
            init_range_high=self.init_range_high,
            crossover_type=self.crossover_type,
            mutation_type=self.mutation_type,
            mutation_percent_genes=self.mutation_percent_genes,
            on_generation=self.on_gen,
            save_solutions=self.save_solutions
        )


    def fitness_function(self, ga_instance, solution, solution_idx):
        penalty = 0
        orders = self.orders
        PAPER_SIZE = self.PAPER_SIZE
        penalty_value = 1000

        for i, var in enumerate(solution):
            if var < 0:  # ถ้ามีค่าน้อยกว่า 0 penalty > กันติดลบ
                penalty += penalty_value

        if sum(solution) > 2:  # ถ้าผลรวมมีค่ามากกว่า 6 penalty > outได้สูงสุด 6 out ต่อรอบ
            penalty += penalty_value*sum(solution)

        if solution[solution >= 1].size > 2:  # out สูงสุด 2 ครั้ง ต่อออร์เดอร์
            penalty += penalty_value

        output = numpy.sum(solution * orders["ตัดกว้าง"])  # ผลรวมของตัดกว้างทั้งหมด

        if output > PAPER_SIZE:  # ถ้าผลรวมมีค่ามากกว่า roll กำหนดขึ้น penalty
            penalty += penalty_value

        fitness_values = -PAPER_SIZE + output  # ผลต่างของกระดาษที่มีกับออเดอร์ ยิ่งเยอะยิ่งดี

        if abs(fitness_values) <= 1.22:  # ถ้าผลรวมมีค่าน้อยกว่า 1.22 penalty > เงื่อนไขบริษัท
            penalty += penalty_value

        return fitness_values - penalty  # ลบด้วย penalty

    def on_gen(self, ga_instance):
        orders = self.orders

        solution = ga_instance.best_solution()[0]

        output = orders.copy()
        output['out'] = solution

        if not self.showZero:
            output = output[output["out"] >= 1]
        output = output.reset_index(drop=True)

        self.fitness_values = ga_instance.best_solution()[1]
        self.output = output

        if self.showOutput:
            self.show(ga_instance, output)

    def show(self, ga_instance, output):
        PAPER_SIZE = self.PAPER_SIZE
        print("Generation : ", ga_instance.generations_completed)
        print("Solution :")

        with pd.option_context(
            "display.max_columns",
            None,
            "display.width",
            None,
            "display.colheader_justify",
            "left",
        ):
            print(output.to_string(index=False))

        print("Roll :", PAPER_SIZE)
        print("Used :", PAPER_SIZE + self.fitness_values)
        print("Trim :", abs(self.fitness_values))
        print("\n")

    def get(self):
        return self.model

# %%
ROLL_PAPER = [68, 73, 75, 79, 82, 85, 88, 91, 95, 97]


def handle_optimization():
    size_value = 73
    file_path = './data/true_ordplan.csv'

    orders = ORD(file_path, deadline_scope=-1, filter=True, filter_value=8, size=size_value, tuning_values=2, common=False).get()
    
    ga_instance = GA(orders, size=size_value, num_generations=50,showOutput=True,save_solutions=False,showZero=False)
    ga_instance.get().run()
    ga_instance.get().plot_fitness()
    
    
    output_data = ga_instance.output.to_dict('records')
    fitness_values = ga_instance.fitness_values

    results = {
        'output': output_data,
        'trim': abs(fitness_values)
    }

    return results


results = handle_optimization()
# Out:
# c:\Users\user\Desktop\paper_cutting_project\.venv\Lib\site-packages\pygad\pygad.py:1139: UserWarning: The 'delay_after_gen' parameter is deprecated starting from PyGAD 3.3.0. To delay or pause the evolution after each generation, assign a callback function/method to the 'on_generation' parameter to adds some time delay.
#   warnings.warn("The 'delay_after_gen' parameter is deprecated starting from PyGAD 3.3.0. To delay or pause the evolution after each generation, assign a callback function/method to the 'on_generation' parameter to adds some time delay.")
#
# x28554          5/22/2023  KS231    CM127     0        0  KB230   3          32.2441   43.8189   988         Y             4.2559 2
# x27814          5/16/2023  KS231    CM127     0        0  KB230   3          32.2441   43.8189   200         Y             4.2559 1
# x26991           5/9/2023  KS161    CM147     0        0  KB120   3          32.4016   77.1654   600         N             4.0984 2
# x36969          8/26/2023  KS161    CM147     0        0  KB120   3          32.4016   77.1654  1000         N             4.0984 1
# x36970           9/4/2023  KS161    CM147     0        0  KB120   3          32.4016   77.1654  1300         N             4.0984 2
# x33640          6/26/2023  KS161    CM147     0        0  KB120   3          32.4016   77.1654  1000         N             4.0984 1
# x21613           5/5/2023  KS161    CM147     0        0  KB120   3          32.4016   77.1654  3000         N             4.0984 1
# x26213          5/22/2023  KS161    CM147     0        0  KB120   3          32.4016   77.1654  1500         N             4.0984 2
# x26032           5/3/2023  KS121    CM127     0        0  CM127   3          32.5197   52.3228 10000         Y             3.9803 1
# x29372          5/27/2023  KS121    CM127     0        0  CM127   3          32.5197   52.3228  3000         Y             3.9803 2
# x33577          6/28/2023  KS121    CM127     0        0  CM127   3          32.5197   52.3228  3000         Y             3.9803 1
# x36199          7/14/2023  KS231    CM127     0        0  KB160   3          32.5984   52.4803  1750         Y             3.9016 1
# x37277          7/21/2023  KS231    CM127     0        0  KB160   3          32.5984   52.4803   585         Y             3.9016 1
# x27430          5/13/2023  KS231    CM127     0        0  KB160   3          32.5984   52.4803   273         Y             3.9016 1
# x36210          7/14/2023  KS231    CM127     0        0  KB160   3          32.5984   52.4803   197         Y             3.9016 1
# x33807          6/30/2023  KS231    CM127     0        0  KB160   3          32.5984   52.4803   457         Y             3.9016 1
# x38995           8/5/2023  KS231    CM127     0        0  KB160   3          32.5984   52.4803   428         Y             3.9016 1
# x39452           8/8/2023  KS231    CM127     0        0  KB160   3          32.5984   52.4803   622         Y             3.9016 2
# x30178           6/2/2023  KS231    CM127     0        0  KB160   3          32.5984   42.8740   133         Y             3.9016 1
# x32396          6/20/2023  KS231    CM127     0        0  KB160   3          32.5984   52.4803   273         Y             3.9016 1
# x28782          5/23/2023  KS231    CM127     0        0  KB160   3          32.5984   52.4803   167         Y             3.9016 1
# x36909          7/19/2023 KAC125        0     0    CM127  KB120   3          32.7953   51.0630  1250         Y             3.7047 2
# x26277           5/5/2023  KI158    CM147     0        0  KB160   3          32.7953   79.2126  1000         N             3.7047 2
# x37122          7/20/2023  CM112    CM127     0        0  CM112   3          32.7953   38.8583  1000         Y             3.7047 2
# x37118          7/20/2023  CM112    CM127     0        0  CM112   3          32.7953   38.8583  1000         Y             3.7047 1
# x31233          6/10/2023 KAC125        0     0    CM127  KB120   3          32.7953   51.0630  1250         Y             3.7047 2
# x32203          6/15/2023  KI128    CM127     0        0  CM112   3          33.0315   67.6378  1500         N             3.4685 1
# x32258          6/17/2023  KI128    CM127     0        0  CM112   3          33.0315   67.6378  7200         N             3.4685 2
# x28330          5/20/2023 KAC125        0     0    CM127  KB120   3          33.1102   57.0866  2500         Y             3.3898 1
# x29299          5/27/2023  KA125        0     0    CM112  CM112   3          33.1102   57.0866   375         Y             3.3898 1
# x24317           5/6/2023  KS161    CM147     0        0  KB120   3          33.1890   68.1102   800         N             3.3110 2
# x33641          6/26/2023  KS161    CM127     0        0  KB120   3          33.1890   72.8346   600         N             3.3110 2
# x33643          6/26/2023  KS161    CM127     0        0  KB120   3          33.1890   72.8346  1000         N             3.3110 1
# x37949          7/24/2023  KS161    CM127     0        0  KB120   3          33.1890   72.8346  1900         N             3.3110 1
# x37946          7/24/2023  KS161    CM127     0        0  KB120   3          33.1890   72.8346  1000         N             3.3110 2
# x32790          7/26/2023  KS161    CM147     0        0  KB120   3          33.1890   68.1102  1000         N             3.3110 2
# x37942          7/24/2023  KS161    CM147     0        0  KB120   3          33.1890   68.1102   600         N             3.3110 2
# x24315           5/3/2023  KS161    CM127     0        0  KB120   3          33.1890   72.8
# Solution :
# เลขที่ใบสั่งขาย กำหนดส่ง  แผ่นหน้า ลอน C แผ่นกลาง ลอน B แผ่นหลัง  จำนวนชั้น  ตัดกว้าง  ตัดยาว  จำนวนสั่งขาย ประเภททับเส้น  diff   out
# x33640          6/26/2023 KS161    CM147 0        0     KB120    3          32.4016   77.1654 1000          N             4.0984 1
# x38995           8/5/2023 KS231    CM127 0        0     KB160    3          32.5984   52.4803  428          Y             3.9016 1
# Roll : 73
# Used : 65.0
# Trim : 8.0
#
#
# Generation :  40
# Solution :
# เลขที่ใบสั่งขาย กำหนดส่ง  แผ่นหน้า ลอน C แผ่นกลาง ลอน B แผ่นหลัง  จำนวนชั้น  ตัดกว้าง  ตัดยาว  จำนวนสั่งขาย ประเภททับเส้น  diff   out
# x37944          7/24/2023 KS231    CM197 0        0     KB230    3          30.1181   59.0551 1000          N             6.3819 1
# x36578          7/18/2023 KS231    CM127 0        0     KB230    3          41.4567   35.1575  333          Y             4.9567 1
# Roll : 73
# Used : 71.5748
# Trim : 1.4252000000000038
#
#
# Generation :  41
# Solution :
# เลขที่ใบสั่งขาย กำหนดส่ง  แผ่นหน้า ลอน C แผ่นกลาง ลอน B แผ่นหลัง  จำนวนชั้น  ตัดกว้าง  ตัดยาว  จำนวนสั่งขาย ประเภททับเส้น  diff   out
# x37944          7/24/2023 KS231    CM197 0        0     KB230    3          30.1181   59.0551 1000          N             6.3819 1
# x36578          7/18/2023 KS231    CM127 0        0     KB230    3          41.4567   35.1575  333          Y             4.9567 1
# Roll : 73
# Used : 71.5748
# Trim : 1.4252000000000038
#
#
# Generation :  42
# Solution :
# เลขที่ใบสั่งขาย กำหนดส่ง  แผ่นหน้า ลอน C แผ่นกลาง ลอน B แผ่นหลัง  จำนวนชั้น  ตัดกว้าง  ตัดยาว  จำนวนสั่งขาย ประเภททับเส้น  diff   out
# x32239          6/15/2023 KS231    CM197 0        0     KB230    3          30.1181   63.7795 1200          N             6.3819 1
# x36578          7/18/2023 KS231    CM127 0        0     KB230    3          41.4567   35.1575  333          Y             4.9567 1
# Roll : 73
# Used : 71.5748
# Trim : 1.4252000000000038
#
#
# Generation :  43
# Solution :
# เลขที่ใบสั่งขาย กำหนดส่ง  แผ่นหน้า ลอน C แผ่นกลาง ลอน B แผ่นหลัง  จำนวนชั้น  ตัดกว้าง  ตัดยาว  จำนวนสั่งขาย ประเภททับเส้น  diff   out
# x32239          6/15/2023 KS231    CM197 0        0     KB230    3          30.1181   63.7795 1200          N             6.3819 1
# x36578          7/18/2023 KS231    CM127 0        0     KB230    3          41.4567   35.1575  333          Y             4.9567 1
# Roll : 73
# Used : 71.5748
# Trim : 1.4252000000000038
#
#
# Generation :  44
# Solution :
# เลขที่ใบสั่งขาย กำหนดส่ง  แผ่นหน้า ลอน C แผ่นกลาง ลอน B แผ่นหลัง  จำนวนชั้น  ตัดกว้าง  ตัดยาว  จำนวนสั่งขาย ประเภททับเส้น  diff   out
# x32239          6/15/2023 KS231    CM197 0        0     KB230    3          30.1181   63.7795 1200          N             6.3819 1
# x36578          7/18/2023 KS231    CM127 0        0     KB230    3          41.4567   35.1575  333          Y             4.9567 1
# Roll : 73
# Used : 71.5748
# Trim : 1.4252000000000038
#
#
# Generation :  45
# Solution :
# เลขที่ใบสั่งขาย กำหนดส่ง  แผ่นหน้า ลอน C แผ่นกลาง ลอน B แผ่นหลัง  จำนวนชั้น  ตัดกว้าง  ตัดยาว  จำนวนสั่งขาย ประเภททับเส้น  diff   out
# x32239          6/15/2023 KS231    CM197 0        0     KB230    3          30.1181   63.7795 1200          N             6.3819 1
# x36578          7/18/2023 KS231    CM127 0        0     KB230    3          41.4567   35.1575  333          Y             4.9567 1
# Roll : 73
# Used : 71.5748
# Trim : 1.4252000000000038
#
#
# Generation :  46
# Solution :
# เลขที่ใบสั่งขาย กำหนดส่ง  แผ่นหน้า ลอน C แผ่นกลาง ลอน B แผ่นหลัง  จำนวนชั้น  ตัดกว้าง  ตัดยาว  จำนวนสั่งขาย ประเภททับเส้น  diff   out
# x32239          6/15/2023 KS231    CM197 0        0     KB230    3          30.1181   63.7795 1200          N             6.3819 1
# x36578          7/18/2023 KS231    CM127 0        0     KB230    3          41.4567   35.1575  333          Y             4.9567 1
# Roll : 73
# Used : 71.5748
# Trim : 1.4252000000000038
#
#
# Generation :  47
# Solution :
# เลขที่ใบสั่งขาย กำหนดส่ง  แผ่นหน้า ลอน C แผ่นกลาง ลอน B แผ่นหลัง  จำนวนชั้น  ตัดกว้าง  ตัดยาว  จำนวนสั่งขาย ประเภททับเส้น  diff   out
# x32239          6/15/2023 KS231    CM197 0        0     KB230    3          30.1181   63.7795 1200          N             6.3819 1
# x36578          7/18/2023 KS231    CM127 0        0     KB230    3          41.4567   35.1575  333          Y             4.9567 1
# Roll : 73
# Used : 71.5748
# Trim : 1.4252000000000038
#
#
# Generation :  48
# Solution :
# เลขที่ใบสั่งขาย กำหนดส่ง  แผ่นหน้า ลอน C แผ่นกลาง ลอน B แผ่นหลัง  จำนวนชั้น  ตัดกว้าง  ตัดยาว  จำนวนสั่งขาย ประเภททับเส้น  diff   out
# x32239          6/15/2023 KS231    CM197 0        0     KB230    3          30.1181   63.7795 1200          N             6.3819 1
# x36578          7/18/2023 KS231    CM127 0        0     KB230    3          41.4567   35.1575  333          Y             4.9567 1
# Roll : 73
# Used : 71.5748
# Trim : 1.4252000000000038
#
#
# Generation :  49
# Solution :
# เลขที่ใบสั่งขาย กำหนดส่ง  แผ่นหน้า ลอน C แผ่นกลาง ลอน B แผ่นหลัง  จำนวนชั้น  ตัดกว้าง  ตัดยาว  จำนวนสั่งขาย ประเภททับเส้น  diff   out
# x32239          6/15/2023 KS231    CM197 0        0     KB230    3          30.1181   63.7795 1200          N             6.3819 1
# x36578          7/18/2023 KS231    CM127 0        0     KB230    3          41.4567   35.1575  333          Y             4.9567 1
# Roll : 73
# Used : 71.5748
# Trim : 1.4252000000000038
#
#
# Generation :  50
# Solution :
# เลขที่ใบสั่งขาย กำหนดส่ง  แผ่นหน้า ลอน C แผ่นกลาง ลอน B แผ่นหลัง  จำนวนชั้น  ตัดกว้าง  ตัดยาว  จำนวนสั่งขาย ประเภททับเส้น  diff   out
# x32239          6/15/2023 KS231    CM197 0        0     KB230    3          30.1181   63.7795 1200          N             6.3819 1
# x36578          7/18/2023 KS231    CM127 0        0     KB230    3          41.4567   35.1575  333          Y             4.9567 1
# Roll : 73
# Used : 71.5748
# Trim : 1.4252000000000038
# c:\Users\user\Desktop\paper_cutting_project\.venv\Lib\site-packages\pygad\visualize\plot.py:109: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   matplotlib.pyplot.legend()

# %%
def handle_common(results):
    fitness_values=0
    i = 0
    while i < len(results['output']):
        if 'ตัดกว้าง' in results['output'][i]:
            size_value = results['output'][i]['ตัดกว้าง'] + results['trim']
            file_path = './data/true_ordplan.csv'

            orders = ORD(file_path, deadline_scope=-1, filter=False, filter_value=4, size=size_value, tuning_values=2, common=True).get()
            
            ga_instance = GA(orders, size=size_value, num_generations=50, showOutput=True, save_solutions=False, showZero=False)
            ga_instance.get().run()
            ga_instance.get().plot_fitness()
            
            if fitness_values < abs(ga_instance.fitness_values):
                output_data = ga_instance.output.to_dict('records')
                fitness_values = abs(ga_instance.fitness_values)

        i += 1

    # if results['trim'] < fitness_values:
    #     return results

    results = {
        'results': results,
        'common': output_data,
        'trim': fitness_values
    }

    return results

results = handle_common(results)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_22460\3126941085.py:32: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   temp = new_orders[new_orders.apply(lambda order: all(init_order[i] == order[i] for i in [3, 4, 5, 6, 7, 8, 12]), axis=1)]
# c:\Users\user\Desktop\paper_cutting_project\.venv\Lib\site-packages\pygad\pygad.py:1139: UserWarning: The 'delay_after_gen' parameter is deprecated starting from PyGAD 3.3.0. To delay or pause the evolution after each generation, assign a callback function/method to the 'on_generation' parameter to adds some time delay.
#   warnings.warn("The 'delay_after_gen' parameter is deprecated starting from PyGAD 3.3.0. To delay or pause the evolution after each generation, assign a callback function/method to the 'on_generation' parameter to adds some time delay.")
# Generation :  1
# Solution :
# เลขที่ใบสั่งขาย กำหนดส่ง  แผ่นหน้า ลอน C แผ่นกลาง ลอน B แผ่นหลัง  จำนวนชั้น  ตัดกว้าง  ตัดยาว  จำนวนสั่งขาย ประเภททับเส้น  diff    out
# x25769           5/1/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   44.0945  1200         Y             4.15745 1
# x25527           5/2/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  5000         Y             4.15745 0
# x25766           5/2/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   44.0945  1200         Y             4.15745 2
# x26096           5/5/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  7000         Y             4.15745 1
# x26125           5/5/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  5000         Y             4.15745 0
# x26310           5/6/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  4000         Y             4.15745 0
# x26311           5/6/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  4000         Y             4.15745 0
# x26363           5/6/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  1300         Y             4.15745 0
# x26887          5/10/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  6000         Y             4.15745 1
# x27180          5/11/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  2730         Y             4.15745 2
# x27230          5/11/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  5000         Y             4.15745 0
# x27309          5/12/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  6000         Y             4.15745 0
# x27329          5/13/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  1350         Y             4.15745 0
# x27482          5/15/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  2730         Y             4.15745 2
# x27846          5/17/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465 10000         Y             4.15745 0
# x27849          5/17/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  5450         Y             4.15745 1
# x28162          5/18/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  8000         Y             4.15745 0
# x27940          5/18/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   44.0945  3200         Y             4.15745 1
# x27942          5/18/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   44.0945  3200         Y             4.15745 1
# x28324          5/20/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  8000         Y             4.15745 0
# x28326          5/20/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  5000         Y             4.15745 0
# x28853          5/23/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   44.0945  3200         Y             4.15745 1
# x28906          5/24/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  5000         Y             4.15745 0
# x28856          5/24/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   44.0945  4540         Y             4.15745 2
# x29104          5/25/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465 10000         Y             4.15745 0
# x29106          5/25/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  5000         Y             4.15745 0
# x29309          5/27/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465 10000         Y             4.15745 1
# x29310          5/27/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  5000         Y             4.15745 0
# x29590          5/30/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  5000         Y             4.15745 1
# x30161           6/1/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465 10000         Y             4.15745 0
# x30162           6/1/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  5000         Y             4.15745 0
# x30389           6/6/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  6000         Y             4.15745 2
# x30390           6/6/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  3000         Y             4.15745 0
# x30525           6/7/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  5000         Y             4.15745 0
# x31052           6/9/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  2730         Y             4.15745 1
# x30804           6/9/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   44.0945  2800         Y             4.15745 2
# x30806           6/9/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   44.0945  1460         Y             4.15745 2
# x31228          6/10/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  2420         Y             4.15745 0
# x31252          6/12/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  2700         Y             4.15745 2
# x31510          6/13/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  1350         Y             4.15745 1
# x31670          6/15/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   44.0945  2000         Y             4.15745 1
# x31673          6/15/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   44.0945  1200         Y             4.15745 0
# x31972          6/16/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  2700         Y             4.15745 1
# x32265          6/19/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  1350         Y             4.15745 0
# x32390          6/20/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  1350         Y             4.15745 1
# x32745          6/21/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  3000         Y             4.15745 2
# x33056          6/24/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  5000         Y             4.15745 0
# x33162          6/26/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465   500         Y             4.15745 0
# x33258          6/27/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  5000         Y             4.15745 0
# x33579          6/28/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  3000         Y             4.15745 0
# x33896           7/1/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  5000         Y             4.15745 1
# x34475           7/5/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  2800         Y             4.15745 1
# x34849           7/6/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  2700         Y             4.15745 0
# x35341           7/8/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  1860         Y             4.15745 1
# x35344           7/8/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  2650         Y             4.15745 0
# x35388           7/8/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  5000         Y             4.15745 0
# x35395           7/8/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465   950         Y             4.15745 2
# x35469          7/10/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  4000         Y             4.15745 2
# x35482          7/11/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  6000         Y             4.15745 0
# x35934          7/11/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  6000         Y             4.15745 0
# x35936          7/11/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  4000         Y             4.15745 0
# x36088          7/12/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  6000         Y             4.15745 0
#
7/8/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  5000         Y             4.15745 0
# x35395           7/8/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465   950         Y             4.15745 0
# x35469          7/10/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  4000         Y             4.15745 1
# x35482          7/11/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  6000         Y             4.15745 0
# x35934          7/11/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  6000         Y             4.15745 0
# x35936          7/11/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  4000         Y             4.15745 0
# x36088          7/12/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  6000         Y             4.15745 2
# x36113          7/13/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  8000         Y             4.15745 0
# x36327          7/15/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  7000         Y             4.15745 0
# x36720          7/18/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  6000         Y             4.15745 0
# x37357          7/21/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465 10000         Y             4.15745 1
# x37401          7/22/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  8000         Y             4.15745 0
# x37464          7/24/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  5000         Y             4.15745 0
# x37624          7/25/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  5000         Y             4.15745 2
# x38090          7/27/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  8000         Y             4.15745 0
# x38769           8/3/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  4000         Y             4.15745 1
# x38977           8/4/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  1370         Y             4.15745 0
# x39515           8/9/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  5000         Y             4.15745 0
# x39767           8/9/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  8000         Y             4.15745 0
# x39802          8/10/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  5000         Y             4.15745 0
# x39995          8/14/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  5000         Y             4.15745 0
# x40060          8/15/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  3000         Y             4.15745 2
# Roll : 31.543300000000002
# Used : -42523.817800000004
# Trim : 42555.3611
#
#
# Generation :  4
# Solution :
# เลขที่ใบสั่งขาย กำหนดส่ง  แผ่นหน้า ลอน C แผ่นกลาง ลอน B แผ่นหลัง  จำนวนชั้น  ตัดกว้าง  ตัดยาว  จำนวนสั่งขาย ประเภททับเส้น  diff    out
# x25769           5/1/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   44.0945  1200         Y             4.15745 0
# x25527           5/2/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  5000         Y             4.15745 0
# x25766           5/2/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   44.0945  1200         Y             4.15745 1
# x26096           5/5/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  7000         Y             4.15745 1
# x26125           5/5/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  5000         Y             4.15745 0
# x26310           5/6/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  4000         Y             4.15745 0
# x26311           5/6/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  4000         Y             4.15745 0
# x26363           5/6/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  1300         Y             4.15745 0
# x26887          5/10/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  6000         Y             4.15745 2
# x27180          5/11/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  2730         Y             4.15745 0
# x27230          5/11/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  5000         Y             4.15745 0
# x27309          5/12/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  6000         Y             4.15745 1
# x27329          5/13/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  1350         Y             4.15745 0
# x27482          5/15/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  2730         Y             4.15745 0
# x27846          5/17/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465 10000         Y             4.15745 0
# x27849          5/17/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  5450         Y             4.15745 0
# x28162          5/18/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  8000         Y             4.15745 0
# x27940          5/18/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   44.0945  3200         Y             4.15745 2
# x27942          5/18/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   44.0945  3200         Y             4.15745 2
# x28324          5/20/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  8000         Y             4.15745 1
# x28326          5/20/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  5000         Y             4.15745 0
# x28853          5/23/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   44.0945  3200         Y             4.15745 1
# x28906          5/24/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  5000         Y             4.15745 0
# x28856          5/24/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   44.0945  4540         Y             4.15745 1
# x29104          5/25/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465 10000         Y             4.15745 0
# x29106          5/25/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  5000         Y             4.15745 0
# x29309          5/27/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465 10000         Y             4.15745 1
# x29310          5/27/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  5000         Y             4.15745 0
# x29590          5/30/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  5000         Y             4.15745 1
# x30161           6/1/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465 10000         Y             4.15745 0
# x30162           6/1/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  5000         Y             4.15745 1
# x30389           6/6/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  6000         Y             4.15745 0
# x30390           6/6/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  3000         Y             4.15745 0
# x30525           6/7/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  5000         Y             4.15745 1
# x31052           6/9/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  2730         Y             4.15745 1
# x30804           6/9/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   44.0945  2800         Y             4.15745 2
# x30806           6/9/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   44.0945  1460         Y             4.15745 1
# x31228          6/10/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  2420         Y             4.15745 1
# x31252          6/12/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  2700         Y             4.15745 0
# x31510          6/13/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  1350         Y             4.15745 1
# x31670          6/15/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   44.0945  2000         Y             4.15745 0
# x31673          6/15/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   44.0945  1200         Y             4.15745 1
# x31972          6/16/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  2700         Y             4.15745 1
# x32265          6/19/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  1350         Y             4.15745 0
# x32390          6/20/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  1350         Y             4.15745 0
# x32745          6/21/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  3000         Y             4.15745 1
# x33056          6/24/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  5000         Y             4.15745 0
# x33162          6/26/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465   500         Y             4.15745 0
# x33258          6/27/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  5000         Y             4.15745 1
# x33579          6/28/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  3000         Y             4.15745 0
# x33896           7/1/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  5000         Y             4.15745 1
# x34475           7/5/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  2800         Y             4.15745 0
# x34849           7/6/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  2700         Y             4.15745 0
# x35341           7/8/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  1860         Y             4.15745 0
# x35344           7/8/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  2650         Y             4.15745 0
# x35388           7/8/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  5000         Y             4.15745 0
# x35395           7/8/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465   950         Y             4.15745 2
# x35469          7/10/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  4000         Y             4.15745 0
# x35482          7/11/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  6000         Y             4.15745 1
# x35934          7/11/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  6000         Y             4.15745 0
# x35936          7/11/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  4000         Y             4.15745 2
# x36088          7/12/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  6000         Y             4.15745 0
# x36113          7/13/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  8000         Y             4.15745 0
# x36327          7/15/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  7000         Y             4.15745 1
# x36720          7/18/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  6000         Y             4.15745 0
# x37357          7/21/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465 10000         Y             4.15745 1
# x37401          7/22/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  8000         Y             4.15745 0
# x37464          7/24/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  5000         Y             4.15745 0
# x37624          7/25/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  5000         Y             4.15745 0
# x38090          7/27/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  8000         Y             4.15745 2
# x38769           8/3/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  4000         Y             4.15745 0
# x38977           8/4/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  1370         Y             4.15745 0
# x39515           8/9/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  5000         Y             4.15745 0
# x39767           8/9/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  8000         Y             4.15745 0
# x39802          8/10/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  5000         Y             4.15745 0
# x39995          8/14/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  5000         Y             4.15745 0
# x40060          8/15/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  3000         Y             4.15745 0
# Roll : 31.543300000000002
# Used : -37581.8888
# Trim : 37613.4321
#
#
# Generation :  5
# Solution :
# เลขที่ใบสั่งขาย กำหนดส่ง  แผ่นหน้า ลอน C แผ่นกลาง ลอน B แผ่นหลัง  จำนวนชั้น  ตัดกว้าง  ตัดยาว  จำนวนสั่งขาย ประเภททับเส้น  diff    out
# x25769           5/1/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   44.0945  1200         Y             4.15745 0
# x25527           5/2/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  5000         Y             4.15745 2
# x25766           5/2/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   44.0945  1200         Y             4.15745 0
# x26096           5/5/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  7000         Y             4.15745 0
# x26125           5/5/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  5000         Y             4.15745 0
# x26310           5/6/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  4000         Y             4.15745 0
# x26311           5/6/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  4000         Y             4.15745 0
# x26363           5/6/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  1300         Y             4.15745 0
# x26887          5/10/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  6000         Y             4.15745 0
# x27180          5/11/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  2730         Y             4.15745 2
# x27230          5/11/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  5000         Y             4.15745 0
# x27309          5/12/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  6000         Y             4.15745 0
# x27329          5/13/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  1350         Y             4.15745 1
# x27482          5/15/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  2730         Y             4.15745 0
# x27846          5/17/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465 10000         Y             4.15745 1
# x27849          5/17/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  5450         Y             4.15745 0
# x28162          5/18/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  8000         Y             4.15745 0
# x27940          5/18/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   44.0945  3200         Y             4.15745 2
# x27942          5/18/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   44.0945  3200         Y             4.15745 1
# x28324          5/20/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  8000         Y             4.15745 0
# x28326          5/20/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  5000         Y             4.15745 0
# x28853          5/23/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   44.0945  3200         Y             4.15745 1
# x28906          5/24/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  5000         Y             4.15745 0
# x28856          5/24/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   44.0945  4540         Y             4.15745 1
# x29104          5/25/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465 10000         Y             4.15745 0
# x29106          5/25/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  5000         Y             4.15745 0
# x29309          5/27/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465 10000         Y             4.15745 1
# x29310          5/27/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  5000         Y             4.15745 0
# x29590          5/30/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  5000         Y             4.15745 0
# x30161           6/1/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465 10000         Y             4.15745 0
# x30162           6/1/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  5000         Y             4.15745 0
# x30389           6/6/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  6000         Y             4.15745 2
# ...
# x31670          6/15/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   44.0945  2000         Y             9.82675 1
# x31673          6/15/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   44.0945  1200         Y             9.82675 0
# x31972          6/16/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  2700         Y             9.82675 0
# x32265          6/19/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  1350         Y             9.82675 0
# x32390          6/20/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  1350         Y             9.82675 0
# x32745          6/21/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  3000         Y             9.82675 0
# x33056          6/24/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  5000         Y             9.82675 0
# x33162          6/26/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465   500         Y             9.82675 0
# x33258          6/27/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  5000         Y             9.82675 0
# x33579          6/28/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  3000         Y             9.82675 1
# x33896           7/1/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  5000         Y             9.82675 0
# x34475           7/5/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  2800         Y             9.82675 0
# x34849           7/6/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  2700         Y             9.82675 0
# x35341           7/8/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  1860         Y             9.82675 0
# x35344           7/8/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  2650         Y             9.82675 0
# x35388           7/8/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  5000         Y             9.82675 0
# x35395           7/8/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465   950         Y             9.82675 0
# x35469          7/10/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  4000         Y             9.82675 0
# x35482          7/11/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  6000         Y             9.82675 0
# x35934          7/11/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  6000         Y             9.82675 0
# x35936          7/11/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  4000         Y             9.82675 0
# x36088          7/12/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  6000         Y             9.82675 0
# x36113          7/13/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  8000         Y             9.82675 0
# x36327          7/15/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  7000         Y             9.82675 0
# x36720          7/18/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  6000         Y             9.82675 0
# x37357          7/21/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465 10000         Y             9.82675 0
# x37401          7/22/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  8000         Y             9.82675 0
# x37464          7/24/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  5000         Y             9.82675 0
# x37624          7/25/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  5000         Y             9.82675 0
# x38090          7/27/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  8000         Y             9.82675 0
# x38769           8/3/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  4000         Y             9.82675 0
# x38977           8/4/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  1370         Y             9.82675 0
# x39515           8/9/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  5000         Y             9.82675 0
# x39767           8/9/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  8000         Y             9.82675 0
# x39802          8/10/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  5000         Y             9.82675 0
# x39995          8/14/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  5000         Y             9.82675 0
# x40060          8/15/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  3000         Y             9.82675 0
# Roll : 42.8819
# Used : 23.2284
# Trim : 19.6535
#
#
# Generation :  50
# Solution :
# เลขที่ใบสั่งขาย กำหนดส่ง  แผ่นหน้า ลอน C แผ่นกลาง ลอน B แผ่นหลัง  จำนวนชั้น  ตัดกว้าง  ตัดยาว  จำนวนสั่งขาย ประเภททับเส้น  diff    out
# x25769           5/1/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   44.0945  1200         Y             9.82675 0
# x25527           5/2/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  5000         Y             9.82675 0
# x25766           5/2/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   44.0945  1200         Y             9.82675 0
# x26096           5/5/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  7000         Y             9.82675 0
# x26125           5/5/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  5000         Y             9.82675 0
# x26310           5/6/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  4000         Y             9.82675 0
# x26311           5/6/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  4000         Y             9.82675 0
# x26363           5/6/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  1300         Y             9.82675 0
# x26887          5/10/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  6000         Y             9.82675 0
# x27180          5/11/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  2730         Y             9.82675 0
# x27230          5/11/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  5000         Y             9.82675 0
# x27309          5/12/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  6000         Y             9.82675 0
# x27329          5/13/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  1350         Y             9.82675 0
# x27482          5/15/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  2730         Y             9.82675 0
# x27846          5/17/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465 10000         Y             9.82675 0
# x27849          5/17/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  5450         Y             9.82675 0
# x28162          5/18/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  8000         Y             9.82675 0
# x27940          5/18/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   44.0945  3200         Y             9.82675 0
# x27942          5/18/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   44.0945  3200         Y             9.82675 0
# x28324          5/20/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  8000         Y             9.82675 0
# x28326          5/20/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  5000         Y             9.82675 0
# x28853          5/23/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   44.0945  3200         Y             9.82675 0
# x28906          5/24/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  5000         Y             9.82675 0
# x28856          5/24/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   44.0945  4540         Y             9.82675 0
# x29104          5/25/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465 10000         Y             9.82675 0
# x29106          5/25/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  5000         Y             9.82675 0
# x29309          5/27/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465 10000         Y             9.82675 0
# x29310          5/27/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  5000         Y             9.82675 0
# x29590          5/30/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  5000         Y             9.82675 0
# x30161           6/1/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465 10000         Y             9.82675 0
# x30162           6/1/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  5000         Y             9.82675 0
# x30389           6/6/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  6000         Y             9.82675 0
# x30390           6/6/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  3000         Y             9.82675 0
# x30525           6/7/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  5000         Y             9.82675 0
# x31052           6/9/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  2730         Y             9.82675 0
# x30804           6/9/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   44.0945  2800         Y             9.82675 0
# x30806           6/9/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   44.0945  1460         Y             9.82675 0
# x31228          6/10/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  2420         Y             9.82675 0
# x31252          6/12/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  2700         Y             9.82675 0
# x31510          6/13/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  1350         Y             9.82675 0
# x31670          6/15/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   44.0945  2000         Y             9.82675 1
# x31673          6/15/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   44.0945  1200         Y             9.82675 0
# x31972          6/16/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  2700         Y             9.82675 0
# x32265          6/19/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  1350         Y             9.82675 0
# x32390          6/20/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  1350         Y             9.82675 0
# x32745          6/21/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  3000         Y             9.82675 0
# x33056          6/24/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  5000         Y             9.82675 0
# x33162          6/26/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465   500         Y             9.82675 0
# x33258          6/27/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  5000         Y             9.82675 0
# x33579          6/28/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  3000         Y             9.82675 1
# x33896           7/1/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  5000         Y             9.82675 0
# x34475           7/5/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  2800         Y             9.82675 0
# x34849           7/6/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  2700         Y             9.82675 0
# x35341           7/8/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  1860         Y             9.82675 0
# x35344           7/8/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  2650         Y             9.82675 0
# x35388           7/8/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  5000         Y             9.82675 0
# x35395           7/8/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465   950         Y             9.82675 0
# x35469          7/10/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  4000         Y             9.82675 0
# x35482          7/11/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  6000         Y             9.82675 0
# x35934          7/11/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  6000         Y             9.82675 0
# x35936          7/11/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  4000         Y             9.82675 0
# x36088          7/12/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  6000         Y             9.82675 0
# x36113          7/13/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  8000         Y             9.82675 0
# x36327          7/15/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  7000         Y             9.82675 0
# x36720          7/18/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  6000         Y             9.82675 0
# x37357          7/21/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465 10000         Y             9.82675 0
# x37401          7/22/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  8000         Y             9.82675 0
# x37464          7/24/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  5000         Y             9.82675 0
# x37624          7/25/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  5000         Y             9.82675 0
# x38090          7/27/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  8000         Y             9.82675 0
# x38769           8/3/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  4000         Y             9.82675 0
# x38977           8/4/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  1370         Y             9.82675 0
# x39515           8/9/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  5000         Y             9.82675 0
# x39767           8/9/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  8000         Y             9.82675 0
# x39802          8/10/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  5000         Y             9.82675 0
# x39995          8/14/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  5000         Y             9.82675 0
# x40060          8/15/2023 CM127    CM127 CM127    CM127 CM127    5          11.6142   23.3465  3000         Y             9.82675 0
# Roll : 42.8819
# Used : 23.2284
# Trim : 19.6535
# c:\Users\user\Desktop\paper_cutting_project\.venv\Lib\site-packages\pygad\visualize\plot.py:109: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   matplotlib.pyplot.legend()

# %%
results
# Out:
# {'results': {'output': [{'เลขที่ใบสั่งขาย': 'x32239',
#     'กำหนดส่ง': '6/15/2023',
#     'แผ่นหน้า': 'KS231',
#     'ลอน C': 'CM197',
#     'แผ่นกลาง': 0,
#     'ลอน B': 0,
#     'แผ่นหลัง': 'KB230',
#     'จำนวนชั้น': 3,
#     'ตัดกว้าง': 30.1181,
#     'ตัดยาว': 63.7795,
#     'จำนวนสั่งขาย': 1200,
#     'ประเภททับเส้น': 'N',
#     'diff': 6.381900000000002,
#     'out': 1},
#    {'เลขที่ใบสั่งขาย': 'x36578',
#     'กำหนดส่ง': '7/18/2023',
#     'แผ่นหน้า': 'KS231',
#     'ลอน C': 'CM127',
#     'แผ่นกลาง': 0,
#     'ลอน B': 0,
#     'แผ่นหลัง': 'KB230',
#     'จำนวนชั้น': 3,
#     'ตัดกว้าง': 41.4567,
#     'ตัดยาว': 35.1575,
#     'จำนวนสั่งขาย': 333,
#     'ประเภททับเส้น': 'Y',
#     'diff': 4.956699999999998,
#     'out': 1}],
#   'trim': np.float64(1.4252000000000038)},
#  'common': [{'เลขที่ใบสั่งขาย': 'x25769',
#    'กำหนดส่ง': '5/1/2023',
#    'แผ่นหน้า': 'CM127',
#    'ลอน C': 'CM127',
#    'แผ่นกลาง': 'CM127',
#    'ลอน B': 'CM127',
#    'แผ่นหลัง': 'CM127',
#    'จำนวนชั้น': 5,
#    'ตัดกว้าง': 11.6142,
#    'ตัดยาว': 44.0945,
#    'จำนวนสั่งขาย': 1200,
#    'ประเภททับเส้น': 'Y',
#    'diff': 9.82675,
#    'out': 0},
#   {'เลขที่ใบสั่งขาย': 'x25527',
#    'กำหนดส่ง': '5/2/2023',
#    'แผ่นหน้า': 'CM127',
#    'ลอน C': 'CM127',
#    'แผ่นกลาง': 'CM127',
#    'ลอน B': 'CM127',
#    'แผ่นหลัง': 'CM127',
#    'จำนวนชั้น': 5,
#    'ตัดกว้าง': 11.6142,
#    'ตัดยาว': 23.3465,
#    'จำนวนสั่งขาย': 5000,
#    'ประเภททับเส้น': 'Y',
#    'diff': 9.82675,
#    'out': 0},
#   {'เลขที่ใบสั่งขาย': 'x25766',
#    'กำหนดส่ง': '5/2/2023',
#    'แผ่นหน้า': 'CM127',
#    'ลอน C': 'CM127',
#    'แผ่นกลาง': 'CM127',
#    'ลอน B': 'CM127',
#    'แผ่นหลัง': 'CM127',
#    'จำนวนชั้น': 5,
#    'ตัดกว้าง': 11.6142,
#    'ตัดยาว': 44.0945,
#    'จำนวนสั่งขาย': 1200,
#    'ประเภททับเส้น': 'Y',
#    'diff': 9.82675,
#    'out': 0},
#   {'เลขที่ใบสั่งขาย': 'x26096',
#    'กำหนดส่ง': '5/5/2023',
#    'แผ่นหน้า': 'CM127',
#    'ลอน C': 'CM127',
#    'แผ่นกลาง': 'CM127',
#    'ลอน B': 'CM127',
#    'แผ่นหลัง': 'CM127',
#    'จำนวนชั้น': 5,
#    'ตัดกว้าง': 11.6142,
#    'ตัดยาว': 23.3465,
#    'จำนวนสั่งขาย': 7000,
#    'ประเภททับเส้น': 'Y',
#    'diff': 9.82675,
#    'out': 0},
#   {'เลขที่ใบสั่งขาย': 'x26125',
#    'กำหนดส่ง': '5/5/2023',
#    'แผ่นหน้า': 'CM127',
#    'ลอน C': 'CM127',
#    'แผ่นกลาง': 'CM127',
#    'ลอน B': 'CM127',
#    'แผ่นหลัง': 'CM127',
#    'จำนวนชั้น': 5,
#    'ตัดกว้าง': 11.6142,
#    'ตัดยาว': 23.3465,
#    'จำนวนสั่งขาย': 5000,
#    'ประเภททับเส้น': 'Y',
#    'diff': 9.82675,
#    'out': 0},
#   {'เลขที่ใบสั่งขาย': 'x26310',
#    'กำหนดส่ง': '5/6/2023',
#    'แผ่นหน้า': 'CM127',
#    'ลอน C': 'CM127',
#    'แผ่นกลาง': 'CM127',
#    'ลอน B': 'CM127',
#    'แผ่นหลัง': 'CM127',
#    'จำนวนชั้น': 5,
#    'ตัดกว้าง': 11.6142,
#    'ตัดยาว': 23.3465,
#    'จำนวนสั่งขาย': 4000,
#    'ประเภททับเส้น': 'Y',
#    'diff': 9.82675,
#    'out': 0},
#   {'เลขที่ใบสั่งขาย': 'x26311',
#    'กำหนดส่ง': '5/6/2023',
#    'แผ่นหน้า': 'CM127',
#    'ลอน C': 'CM127',
#    'แผ่นกลาง': 'CM127',
#    'ลอน B': 'CM127',
#    'แผ่นหลัง': 'CM127',
#    'จำนวนชั้น': 5,
#    'ตัดกว้าง': 11.6142,
#    'ตัดยาว': 23.3465,
#    'จำนวนสั่งขาย': 4000,
#    'ประเภททับเส้น': 'Y',
#    'diff': 9.82675,
#    'out': 0},
#   {'เลขที่ใบสั่งขาย': 'x26363',
#    'กำหนดส่ง': '5/6/2023',
#    'แผ่นหน้า': 'CM127',
#    'ลอน C': 'CM127',
#    'แผ่นกลาง': 'CM127',
#    'ลอน B': 'CM127',
#    'แผ่นหลัง': 'CM127',
#    'จำนวนชั้น': 5,
#    'ตัดกว้าง': 11.6142,
#    'ตัดยาว': 23.3465,
#    'จำนวนสั่งขาย': 1300,
#    'ประเภททับเส้น': 'Y',
#    'diff': 9.82675,
#    'out': 0},
#   {'เลขที่ใบสั่งขาย': 'x26887',
#    'กำหนดส่ง': '5/10/2023',
#    'แผ่นหน้า': 'CM127',
#    'ลอน C': 'CM127',
#    'แผ่นกลาง': 'CM127',
#    'ลอน B': 'CM127',
#    'แผ่นหลัง': 'CM127',
#    'จำนวนชั้น': 5,
#    'ตัดกว้าง': 11.6142,
#    'ตัดยาว': 23.3465,
#    'จำนวนสั่งขาย': 6000,
#    'ประเภททับเส้น': 'Y',
#    'diff': 9.82675,
#    'out': 0},
#   {'เลขที่ใบสั่งขาย': 'x27180',
#    'กำหนดส่ง': '5/11/2023',
#    'แผ่นหน้า': 'CM127',
#    'ลอน C': 'CM127',
#    'แผ่นกลาง': 'CM127',
#    'ลอน B': 'CM127',
#    'แผ่นหลัง': 'CM127',
#    'จำนวนชั้น': 5,
#    'ตัดกว้าง': 11.6142,
#    'ตัดยาว': 23.3465,
#    'จำนวนสั่งขาย': 2730,
#    'ประเภททับเส้น': 'Y',
#    'diff': 9.82675,
#    'out': 0},
#   {'เลขที่ใบสั่งขาย': 'x27230',
#    'กำหนดส่ง': '5/11/2023',
#    'แผ่นหน้า': 'CM127',
#    'ลอน C': 'CM127',
#    'แผ่นกลาง': 'CM127',
#    'ลอน B': 'CM127',
#    'แผ่นหลัง': 'CM127',
#    'จำนวนชั้น': 5,
#    'ตัดกว้าง': 11.6142,
#    'ตัดยาว': 23.3465,
#    'จำนวนสั่งขาย': 5000,
#    'ประเภททับเส้น': 'Y',
#    'diff': 9.82675,
#    'out': 0},
#   {'เลขที่ใบสั่งขาย': 'x27309',
#    'กำหนดส่ง': '5/12/2023',
#    'แผ่นหน้า': 'CM127',
#    'ลอน C': 'CM127',
#    'แผ่นกลาง': 'CM127',
#    'ลอน B': 'CM127',
#    'แผ่นหลัง': 'CM127',
#    'จำนวนชั้น': 5,
#    'ตัดกว้าง': 11.6142,
#    'ตัดยาว': 23.3465,
#    'จำนวนสั่งขาย': 6000,
#    'ประเภททับเส้น': 'Y',
#    'diff': 9.82675,
#    'out': 0},
#   {'เลขที่ใบสั่งขาย': 'x27329',
#    'กำหนดส่ง': '5/13/2023',
#    'แผ่นหน้า': 'CM127',
#    'ลอน C': 'CM127',
#    'แผ่นกลาง': 'CM127',
#    'ลอน B': 'CM127',
#    'แผ่นหลัง': 'CM127',
#    'จำนวนชั้น': 5,
#    'ตัดกว้าง': 11.6142,
#    'ตัดยาว': 23.3465,
#    'จำนวนสั่งขาย': 1350,
#    'ประเภททับเส้น': 'Y',
#    'diff': 9.82675,
#    'out': 0},
#   {'เลขที่ใบสั่งขาย': 'x27482',
#    'กำหนดส่ง': '5/15/2023',
#    'แผ่นหน้า': 'CM127',
#    'ลอน C': 'CM127',
#    'แผ่นกลาง': 'CM127',
#    'ลอน B': 'CM127',
#    'แผ่นหลัง': 'CM127',
#    'จำนวนชั้น': 5,
#    'ตัดกว้าง': 11.6142,
#    'ตัดยาว': 23.3465,
#    'จำนวนสั่งขาย': 2730,
#    'ประเภททับเส้น': 'Y',
#    'diff': 9.82675,
#    'out': 0},
#   {'เลขที่ใบสั่งขาย': 'x27846',
#    'กำหนดส่ง': '5/17/2023',
#    'แผ่นหน้า': 'CM127',
#    'ลอน C': 'CM127',
#    'แผ่นกลาง': 'CM127',
#    'ลอน B': 'CM127',
#    'แผ่นหลัง': 'CM127',
#    'จำนวนชั้น': 5,
#    'ตัดกว้าง': 11.6142,
#    'ตัดยาว': 23.3465,
#    'จำนวนสั่งขาย': 10000,
#    'ประเภททับเส้น': 'Y',
#    'diff': 9.82675,
#    'out': 0},
#   {'เลขที่ใบสั่งขาย': 'x27849',
#    'กำหนดส่ง': '5/17/2023',
#    'แผ่นหน้า': 'CM127',
#    'ลอน C': 'CM127',
#    'แผ่นกลาง': 'CM127',
#    'ลอน B': 'CM127',
#    'แผ่นหลัง': 'CM127',
#    'จำนวนชั้น': 5,
#    'ตัดกว้าง': 11.6142,
#    'ตัดยาว': 23.3465,
#    'จำนวนสั่งขาย': 5450,
#    'ประเภททับเส้น': 'Y',
#    'diff': 9.82675,
#    'out': 0},
#   {'เลขที่ใบสั่งขาย': 'x28162',
#    'กำหนดส่ง': '5/18/2023',
#    'แผ่นหน้า': 'CM127',
#    'ลอน C': 'CM127',
#    'แผ่นกลาง': 'CM127',
#    'ลอน B': 'CM127',
#    'แผ่นหลัง': 'CM127',
#    'จำนวนชั้น': 5,
#    'ตัดกว้าง': 11.6142,
#    'ตัดยาว': 23.3465,
#    'จำนวนสั่งขาย': 8000,
#    'ประเภททับเส้น': 'Y',
#    'diff': 9.82675,
#    'out': 0},
#   {'เลขที่ใบสั่งขาย': 'x27940',
#    'กำหนดส่ง': '5/18/2023',
#    'แผ่นหน้า': 'CM127',
#    'ลอน C': 'CM127',
#    'แผ่นกลาง': 'CM127',
#    'ลอน B': 'CM127',
#    'แผ่นหลัง': 'CM127',
#    'จำนวนชั้น': 5,
#    'ตัดกว้าง': 11.6142,
#    'ตัดยาว': 44.0945,
#    'จำนวนสั่งขาย': 3200,
#    'ประเภททับเส้น': 'Y',
#    'diff': 9.82675,
#    'out': 0},
#   {'เลขที่ใบสั่งขาย': 'x27942',
#    'กำหนดส่ง': '5/18/2023',
#    'แผ่นหน้า': 'CM127',
#    'ลอน C': 'CM127',
#    'แผ่นกลาง': 'CM127',
#    'ลอน B': 'CM127',
#    'แผ่นหลัง': 'CM127',
#    'จำนวนชั้น': 5,
#    'ตัดกว้าง': 11.6142,
#    'ตัดยาว': 44.0945,
#    'จำนวนสั่งขาย': 3200,
#    'ประเภททับเส้น': 'Y',
#    'diff': 9.82675,
#    'out': 0},
#   {'เลขที่ใบสั่งขาย': 'x28324',
#    'กำหนดส่ง': '5/20/2023',
#    'แผ่นหน้า': 'CM127',
#    'ลอน C': 'CM127',
#    'แผ่นกลาง': 'CM127',
#    'ลอน B': 'CM127',
#    'แผ่นหลัง': 'CM127',
#    'จำนวนชั้น': 5,
#    'ตัดกว้าง': 11.6142,
#    'ตัดยาว': 23.3465,
#    'จำนวนสั่งขาย': 8000,
#    'ประเภททับเส้น': 'Y',
#    'diff': 9.82675,
#    'out': 0},
#   {'เลขที่ใบสั่งขาย': 'x28326',
#    'กำหนดส่ง': '5/20/2023',
#    'แผ่นหน้า': 'CM127',
#    'ลอน C': 'CM127',
#    'แผ่นกลาง': 'CM127',
#    'ลอน B': 'CM127',
#    'แผ่นหลัง': 'CM127',
#    'จำนวนชั้น': 5,
#    'ตัดกว้าง': 11.6142,
#    'ตัดยาว': 23.3465,
#    'จำนวนสั่งขาย': 5000,
#    'ประเภททับเส้น': 'Y',
#    'diff': 9.82675,
#    'out': 0},
#   {'เลขที่ใบสั่งขาย': 'x28853',
#    'กำหนดส่ง': '5/23/2023',
#    'แผ่นหน้า': 'CM127',
#    'ลอน C': 'CM127',
#    'แผ่นกลาง': 'CM127',
#    'ลอน B': 'CM127',
#    'แผ่นหลัง': 'CM127',
#    'จำนวนชั้น': 5,
#    'ตัดกว้าง': 11.6142,
#    'ตัดยาว': 44.0945,
#    'จำนวนสั่งขาย': 3200,
#    'ประเภททับเส้น': 'Y',
#    'diff': 9.82675,
#    'out': 0},
#   {'เลขที่ใบสั่งขาย': 'x28906',
#    'กำหนดส่ง': '5/24/2023',
#    'แผ่นหน้า': 'CM127',
#    'ลอน C': 'CM127',
#    'แผ่นกลาง': 'CM127',
#    'ลอน B': 'CM127',
#    'แผ่นหลัง': 'CM127',
#    'จำนวนชั้น': 5,
#    'ตัดกว้าง': 11.6142,
#    'ตัดยาว': 23.3465,
#    'จำนวนสั่งขาย': 5000,
#    'ประเภททับเส้น': 'Y',
#    'diff': 9.82675,
#    'out': 0},
#   {'เลขที่ใบสั่งขาย': 'x28856',
#    'กำหนดส่ง': '5/24/2023',
#    'แผ่นหน้า': 'CM127',
#    'ลอน C': 'CM127',
#    'แผ่นกลาง': 'CM127',
#    'ลอน B': 'CM127',
#    'แผ่นหลัง': 'CM127',
#    'จำนวนชั้น': 5,
#    'ตัดกว้าง': 11.6142,
#    'ตัดยาว': 44.0945,
#    'จำนวนสั่งขาย': 4540,
#    'ประเภททับเส้น': 'Y',
#    'diff': 9.82675,
#    'out': 0},
#   {'เลขที่ใบสั่งขาย': 'x29104',
#    'กำหนดส่ง': '5/25/2023',
#    'แผ่นหน้า': 'CM127',
#    'ลอน C': 'CM127',
#    'แผ่นกลาง': 'CM127',
#    'ลอน B': 'CM127',
#    'แผ่นหลัง': 'CM127',
#    'จำนวนชั้น': 5,
#    'ตัดกว้าง': 11.6142,
#    'ตัดยาว': 23.3465,
#    'จำนวนสั่งขาย': 10000,
#    'ประเภททับเส้น': 'Y',
#    'diff': 9.82675,
#    'out': 0},
#   {'เลขที่ใบสั่งขาย': 'x29106',
#    'กำหนดส่ง': '5/25/2023',
#    'แผ่นหน้า': 'CM127',
#    'ลอน C': 'CM127',
#    'แผ่นกลาง': 'CM127',
#    'ลอน B': 'CM127',
#    'แผ่นหลัง': 'CM127',
#    'จำนวนชั้น': 5,
#    'ตัดกว้าง': 11.6142,
#    'ตัดยาว': 23.3465,
#    'จำนวนสั่งขาย': 5000,
#    'ประเภททับเส้น': 'Y',
#    'diff': 9.82675,
#    'out': 0},
#   {'เลขที่ใบสั่งขาย': 'x29309',
#    'กำหนดส่ง': '5/27/2023',
#    'แผ่นหน้า': 'CM127',
#    'ลอน C': 'CM127',
#    'แผ่นกลาง': 'CM127',
#    'ลอน B': 'CM127',
#    'แผ่นหลัง': 'CM127',
#    'จำนวนชั้น': 5,
#    'ตัดกว้าง': 11.6142,
#    'ตัดยาว': 23.3465,
#    'จำนวนสั่งขาย': 10000,
#    'ประเภททับเส้น': 'Y',
#    'diff': 9.82675,
#    'out': 0},
#   {'เลขที่ใบสั่งขาย': 'x29310',
#    'กำหนดส่ง': '5/27/2023',
#    'แผ่นหน้า': 'CM127',
#    'ลอน C': 'CM127',
#    'แผ่นกลาง': 'CM127',
#    'ลอน B': 'CM127',
#    'แผ่นหลัง': 'CM127',
#    'จำนวนชั้น': 5,
#    'ตัดกว้าง': 11.6142,
#    'ตัดยาว': 23.3465,
#    'จำนวนสั่งขาย': 5000,
#    'ประเภททับเส้น': 'Y',
#    'diff': 9.82675,
#    'out': 0},
#   {'เลขที่ใบสั่งขาย': 'x29590',
#    'กำหนดส่ง': '5/30/2023',
#    'แผ่นหน้า': 'CM127',
#    'ลอน C': 'CM127',
#    'แผ่นกลาง': 'CM127',
#    'ลอน B': 'CM127',
#    'แผ่นหลัง': 'CM127',
#    'จำนวนชั้น': 5,
#    'ตัดกว้าง': 11.6142,
#    'ตัดยาว': 23.3465,
#    'จำนวนสั่งขาย': 5000,
#    'ประเภททับเส้น': 'Y',
#    'diff': 9.82675,
#    'out': 0},
#   {'เลขที่ใบสั่งขาย': 'x30161',
#    'กำหนดส่ง': '6/1/2023',
#    'แผ่นหน้า': 'CM127',
#    'ลอน C': 'CM127',
#    'แผ่นกลาง': 'CM127',
#    'ลอน B': 'CM127',
#    'แผ่นหลัง': 'CM127',
#    'จำนวนชั้น': 5,
#    'ตัดกว้าง': 11.6142,
#    'ตัดยาว': 23.3465,
#    'จำนวนสั่งขาย': 10000,
#    'ประเภททับเส้น': 'Y',
#    'diff': 9.82675,
#    'out': 0},
#   {'เลขที่ใบสั่งขาย': 'x30162',
#    'กำหนดส่ง': '6/1/2023',
#    'แผ่นหน้า': 'CM127',
#    'ลอน C': 'CM127',
#    'แผ่นกลาง': 'CM127',
#    'ลอน B': 'CM127',
#    'แผ่นหลัง': 'CM127',
#    'จำนวนชั้น': 5,
#    'ตัดกว้าง': 11.6142,
#    'ตัดยาว': 23.3465,
#    'จำนวนสั่งขาย': 5000,
#    'ประเภททับเส้น': 'Y',
#    'diff': 9.82675,
#    'out': 0},
#   {'เลขที่ใบสั่งขาย': 'x30389',
#    'กำหนดส่ง': '6/6/2023',
#    'แผ่นหน้า': 'CM127',
#    'ลอน C': 'CM127',
#    'แผ่นกลาง': 'CM127',
#    'ลอน B': 'CM127',
#    'แผ่นหลัง': 'CM127',
#    'จำนวนชั้น': 5,
#    'ตัดกว้าง': 11.6142,
#    'ตัดยาว': 23.3465,
#    'จำนวนสั่งขาย': 6000,
#    'ประเภททับเส้น': 'Y',
#    'diff': 9.82675,
#    'out': 0},
#   {'เลขที่ใบสั่งขาย': 'x30390',
#    'กำหนดส่ง': '6/6/2023',
#    'แผ่นหน้า': 'CM127',
#    'ลอน C': 'CM127',
#    'แผ่นกลาง': 'CM127',
#    'ลอน B': 'CM127',
#    'แผ่นหลัง': 'CM127',
#    'จำนวนชั้น': 5,
#    'ตัดกว้าง': 11.6142,
#    'ตัดยาว': 23.3465,
#    'จำนวนสั่งขาย': 3000,
#    'ประเภททับเส้น': 'Y',
#    'diff': 9.82675,
#    'out': 0},
#   {'เลขที่ใบสั่งขาย': 'x30525',
#    'กำหนดส่ง': '6/7/2023',
#    'แผ่นหน้า': 'CM127',
#    'ลอน C': 'CM127',
#    'แผ่นกลาง': 'CM127',
#    'ลอน B': 'CM127',
#    'แผ่นหลัง': 'CM127',
#    'จำนวนชั้น': 5,
#    'ตัดกว้าง': 11.6142,
#    'ตัดยาว': 23.3465,
#    'จำนวนสั่งขาย': 5000,
#    'ประเภททับเส้น': 'Y',
#    'diff': 9.82675,
#    'out': 0},
#   {'เลขที่ใบสั่งขาย': 'x31052',
#    'กำหนดส่ง': '6/9/2023',
#    'แผ่นหน้า': 'CM127',
#    'ลอน C': 'CM127',
#    'แผ่นกลาง': 'CM127',
#    'ลอน B': 'CM127',
#    'แผ่นหลัง': 'CM127',
#    'จำนวนชั้น': 5,
#    'ตัดกว้าง': 11.6142,
#    'ตัดยาว': 23.3465,
#    'จำนวนสั่งขาย': 2730,
#    'ประเภททับเส้น': 'Y',
#    'diff': 9.82675,
#    'out': 0},
#   {'เลขที่ใบสั่งขาย': 'x30804',
#    'กำหนดส่ง': '6/9/2023',
#    'แผ่นหน้า': 'CM127',
#    'ลอน C': 'CM127',
#    'แผ่นกลาง': 'CM127',
#    'ลอน B': 'CM127',
#    'แผ่นหลัง': 'CM127',
#    'จำนวนชั้น': 5,
#    'ตัดกว้าง': 11.6142,
#    'ตัดยาว': 44.0945,
#    'จำนวนสั่งขาย': 2800,
#    'ประเภททับเส้น': 'Y',
#    'diff': 9.82675,
#    'out': 0},
#   {'เลขที่ใบสั่งขาย': 'x30806',
#    'กำหนดส่ง': '6/9/2023',
#    'แผ่นหน้า': 'CM127',
#    'ลอน C': 'CM127',
#    'แผ่นกลาง': 'CM127',
#    'ลอน B': 'CM127',
#    'แผ่นหลัง': 'CM127',
#    'จำนวนชั้น': 5,
#    'ตัดกว้าง': 11.6142,
#    'ตัดยาว': 44.0945,
#    'จำนวนสั่งขาย': 1460,
#    'ประเภททับเส้น': 'Y',
#    'diff': 9.82675,
#    'out': 0},
#   {'เลขที่ใบสั่งขาย': 'x31228',
#    'กำหนดส่ง': '6/10/2023',
#    'แผ่นหน้า': 'CM127',
#    'ลอน C': 'CM127',
#    'แผ่นกลาง': 'CM127',
#    'ลอน B': 'CM127',
#    'แผ่นหลัง': 'CM127',
#    'จำนวนชั้น': 5,
#    'ตัดกว้าง': 11.6142,
#    'ตัดยาว': 23.3465,
#    'จำนวนสั่งขาย': 2420,
#    'ประเภททับเส้น': 'Y',
#    'diff': 9.82675,
#    'out': 0},
#   {'เลขที่ใบสั่งขาย': 'x31252',
#    'กำหนดส่ง': '6/12/2023',
#    'แผ่นหน้า': 'CM127',
#    'ลอน C': 'CM127',
#    'แผ่นกลาง': 'CM127',
#    'ลอน B': 'CM127',
#    'แผ่นหลัง': 'CM127',
#    'จำนวนชั้น': 5,
#    'ตัดกว้าง': 11.6142,
#    'ตัดยาว': 23.3465,
#    'จำนวนสั่งขาย': 2700,
#    'ประเภททับเส้น': 'Y',
#    'diff': 9.82675,
#    'out': 0},
#   {'เลขที่ใบสั่งขาย': 'x31510',
#    'กำหนดส่ง': '6/13/2023',
#    'แผ่นหน้า': 'CM127',
#    'ลอน C': 'CM127',
#    'แผ่นกลาง': 'CM127',
#    'ลอน B': 'CM127',
#    'แผ่นหลัง': 'CM127',
#    'จำนวนชั้น': 5,
#    'ตัดกว้าง': 11.6142,
#    'ตัดยาว': 23.3465,
#    'จำนวนสั่งขาย': 1350,
#    'ประเภททับเส้น': 'Y',
#    'diff': 9.82675,
#    'out': 0},
#   {'เลขที่ใบสั่งขาย': 'x31670',
#    'กำหนดส่ง': '6/15/2023',
#    'แผ่นหน้า': 'CM127',
#    'ลอน C': 'CM127',
#    'แผ่นกลาง': 'CM127',
#    'ลอน B': 'CM127',
#    'แผ่นหลัง': 'CM127',
#    'จำนวนชั้น': 5,
#    'ตัดกว้าง': 11.6142,
#    'ตัดยาว': 44.0945,
#    'จำนวนสั่งขาย': 2000,
#    'ประเภททับเส้น': 'Y',
#    'diff': 9.82675,
#    'out': 1},
#   {'เลขที่ใบสั่งขาย': 'x31673',
#    'กำหนดส่ง': '6/15/2023',
#    'แผ่นหน้า': 'CM127',
#    'ลอน C': 'CM127',
#    'แผ่นกลาง': 'CM127',
#    'ลอน B': 'CM127',
#    'แผ่นหลัง': 'CM127',
#    'จำนวนชั้น': 5,
#    'ตัดกว้าง': 11.6142,
#    'ตัดยาว': 44.0945,
#    'จำนวนสั่งขาย': 1200,
#    'ประเภททับเส้น': 'Y',
#    'diff': 9.82675,
#    'out': 0},
#   {'เลขที่ใบสั่งขาย': 'x31972',
#    'กำหนดส่ง': '6/16/2023',
#    'แผ่นหน้า': 'CM127',
#    'ลอน C': 'CM127',
#    'แผ่นกลาง': 'CM127',
#    'ลอน B': 'CM127',
#    'แผ่นหลัง': 'CM127',
#    'จำนวนชั้น': 5,
#    'ตัดกว้าง': 11.6142,
#    'ตัดยาว': 23.3465,
#    'จำนวนสั่งขาย': 2700,
#    'ประเภททับเส้น': 'Y',
#    'diff': 9.82675,
#    'out': 0},
#   {'เลขที่ใบสั่งขาย': 'x32265',
#    'กำหนดส่ง': '6/19/2023',
#    'แผ่นหน้า': 'CM127',
#    'ลอน C': 'CM127',
#    'แผ่นกลาง': 'CM127',
#    'ลอน B': 'CM127',
#    'แผ่นหลัง': 'CM127',
#    'จำนวนชั้น': 5,
#    'ตัดกว้าง': 11.6142,
#    'ตัดยาว': 23.3465,
#    'จำนวนสั่งขาย': 1350,
#    'ประเภททับเส้น': 'Y',
#    'diff': 9.82675,
#    'out': 0},
#   {'เลขที่ใบสั่งขาย': 'x32390',
#    'กำหนดส่ง': '6/20/2023',
#    'แผ่นหน้า': 'CM127',
#    'ลอน C': 'CM127',
#    'แผ่นกลาง': 'CM127',
#    'ลอน B': 'CM127',
#    'แผ่นหลัง': 'CM127',
#    'จำนวนชั้น': 5,
#    'ตัดกว้าง': 11.6142,
#    'ตัดยาว': 23.3465,
#    'จำนวนสั่งขาย': 1350,
#    'ประเภททับเส้น': 'Y',
#    'diff': 9.82675,
#    'out': 0},
#   {'เลขที่ใบสั่งขาย': 'x32745',
#    'กำหนดส่ง': '6/21/2023',
#    'แผ่นหน้า': 'CM127',
#    'ลอน C': 'CM127',
#    'แผ่นกลาง': 'CM127',
#    'ลอน B': 'CM127',
#    'แผ่นหลัง': 'CM127',
#    'จำนวนชั้น': 5,
#    'ตัดกว้าง': 11.6142,
#    'ตัดยาว': 23.3465,
#    'จำนวนสั่งขาย': 3000,
#    'ประเภททับเส้น': 'Y',
#    'diff': 9.82675,
#    'out': 0},
#   {'เลขที่ใบสั่งขาย': 'x33056',
#    'กำหนดส่ง': '6/24/2023',
#    'แผ่นหน้า': 'CM127',
#    'ลอน C': 'CM127',
#    'แผ่นกลาง': 'CM127',
#    'ลอน B': 'CM127',
#    'แผ่นหลัง': 'CM127',
#    'จำนวนชั้น': 5,
#    'ตัดกว้าง': 11.6142,
#    'ตัดยาว': 23.3465,
#    'จำนวนสั่งขาย': 5000,
#    'ประเภททับเส้น': 'Y',
#    'diff': 9.82675,
#    'out': 0},
#   {'เลขที่ใบสั่งขาย': 'x33162',
#    'กำหนดส่ง': '6/26/2023',
#    'แผ่นหน้า': 'CM127',
#    'ลอน C': 'CM127',
#    'แผ่นกลาง': 'CM127',
#    'ลอน B': 'CM127',
#    'แผ่นหลัง': 'CM127',
#    'จำนวนชั้น': 5,
#    'ตัดกว้าง': 11.6142,
#    'ตัดยาว': 23.3465,
#    'จำนวนสั่งขาย': 500,
#    'ประเภททับเส้น': 'Y',
#    'diff': 9.82675,
#    'out': 0},
#   {'เลขที่ใบสั่งขาย': 'x33258',
#    'กำหนดส่ง': '6/27/2023',
#    'แผ่นหน้า': 'CM127',
#    'ลอน C': 'CM127',
#    'แผ่นกลาง': 'CM127',
#    'ลอน B': 'CM127',
#    'แผ่นหลัง': 'CM127',
#    'จำนวนชั้น': 5,
#    'ตัดกว้าง': 11.6142,
#    'ตัดยาว': 23.3465,
#    'จำนวนสั่งขาย': 5000,
#    'ประเภททับเส้น': 'Y',
#    'diff': 9.82675,
#    'out': 0},
#   {'เลขที่ใบสั่งขาย': 'x33579',
#    'กำหนดส่ง': '6/28/2023',
#    'แผ่นหน้า': 'CM127',
#    'ลอน C': 'CM127',
#    'แผ่นกลาง': 'CM127',
#    'ลอน B': 'CM127',
#    'แผ่นหลัง': 'CM127',
#    'จำนวนชั้น': 5,
#    'ตัดกว้าง': 11.6142,
#    'ตัดยาว': 23.3465,
#    'จำนวนสั่งขาย': 3000,
#    'ประเภททับเส้น': 'Y',
#    'diff': 9.82675,
#    'out': 1},
#   {'เลขที่ใบสั่งขาย': 'x33896',
#    'กำหนดส่ง': '7/1/2023',
#    'แผ่นหน้า': 'CM127',
#    'ลอน C': 'CM127',
#    'แผ่นกลาง': 'CM127',
#    'ลอน B': 'CM127',
#    'แผ่นหลัง': 'CM127',
#    'จำนวนชั้น': 5,
#    'ตัดกว้าง': 11.6142,
#    'ตัดยาว': 23.3465,
#    'จำนวนสั่งขาย': 5000,
#    'ประเภททับเส้น': 'Y',
#    'diff': 9.82675,
#    'out': 0},
#   {'เลขที่ใบสั่งขาย': 'x34475',
#    'กำหนดส่ง': '7/5/2023',
#    'แผ่นหน้า': 'CM127',
#    'ลอน C': 'CM127',
#    'แผ่นกลาง': 'CM127',
#    'ลอน B': 'CM127',
#    'แผ่นหลัง': 'CM127',
#    'จำนวนชั้น': 5,
#    'ตัดกว้าง': 11.6142,
#    'ตัดยาว': 23.3465,
#    'จำนวนสั่งขาย': 2800,
#    'ประเภททับเส้น': 'Y',
#    'diff': 9.82675,
#    'out': 0},
#   {'เลขที่ใบสั่งขาย': 'x34849',
#    'กำหนดส่ง': '7/6/2023',
#    'แผ่นหน้า': 'CM127',
#    'ลอน C': 'CM127',
#    'แผ่นกลาง': 'CM127',
#    'ลอน B': 'CM127',
#    'แผ่นหลัง': 'CM127',
#    'จำนวนชั้น': 5,
#    'ตัดกว้าง': 11.6142,
#    'ตัดยาว': 23.3465,
#    'จำนวนสั่งขาย': 2700,
#    'ประเภททับเส้น': 'Y',
#    'diff': 9.82675,
#    'out': 0},
#   {'เลขที่ใบสั่งขาย': 'x35341',
#    'กำหนดส่ง': '7/8/2023',
#    'แผ่นหน้า': 'CM127',
#    'ลอน C': 'CM127',
#    'แผ่นกลาง': 'CM127',
#    'ลอน B': 'CM127',
#    'แผ่นหลัง': 'CM127',
#    'จำนวนชั้น': 5,
#    'ตัดกว้าง': 11.6142,
#    'ตัดยาว': 23.3465,
#    'จำนวนสั่งขาย': 1860,
#    'ประเภททับเส้น': 'Y',
#    'diff': 9.82675,
#    'out': 0},
#   {'เลขที่ใบสั่งขาย': 'x35344',
#    'กำหนดส่ง': '7/8/2023',
#    'แผ่นหน้า': 'CM127',
#    'ลอน C': 'CM127',
#    'แผ่นกลาง': 'CM127',
#    'ลอน B': 'CM127',
#    'แผ่นหลัง': 'CM127',
#    'จำนวนชั้น': 5,
#    'ตัดกว้าง': 11.6142,
#    'ตัดยาว': 23.3465,
#    'จำนวนสั่งขาย': 2650,
#    'ประเภททับเส้น': 'Y',
#    'diff': 9.82675,
#    'out': 0},
#   {'เลขที่ใบสั่งขาย': 'x35388',
#    'กำหนดส่ง': '7/8/2023',
#    'แผ่นหน้า': 'CM127',
#    'ลอน C': 'CM127',
#    'แผ่นกลาง': 'CM127',
#    'ลอน B': 'CM127',
#    'แผ่นหลัง': 'CM127',
#    'จำนวนชั้น': 5,
#    'ตัดกว้าง': 11.6142,
#    'ตัดยาว': 23.3465,
#    'จำนวนสั่งขาย': 5000,
#    'ประเภททับเส้น': 'Y',
#    'diff': 9.82675,
#    'out': 0},
#   {'เลขที่ใบสั่งขาย': 'x35395',
#    'กำหนดส่ง': '7/8/2023',
#    'แผ่นหน้า': 'CM127',
#    'ลอน C': 'CM127',
#    'แผ่นกลาง': 'CM127',
#    'ลอน B': 'CM127',
#    'แผ่นหลัง': 'CM127',
#    'จำนวนชั้น': 5,
#    'ตัดกว้าง': 11.6142,
#    'ตัดยาว': 23.3465,
#    'จำนวนสั่งขาย': 950,
#    'ประเภททับเส้น': 'Y',
#    'diff': 9.82675,
#    'out': 0},
#   {'เลขที่ใบสั่งขาย': 'x35469',
#    'กำหนดส่ง': '7/10/2023',
#    'แผ่นหน้า': 'CM127',
#    'ลอน C': 'CM127',
#    'แผ่นกลาง': 'CM127',
#    'ลอน B': 'CM127',
#    'แผ่นหลัง': 'CM127',
#    'จำนวนชั้น': 5,
#    'ตัดกว้าง': 11.6142,
#    'ตัดยาว': 23.3465,
#    'จำนวนสั่งขาย': 4000,
#    'ประเภททับเส้น': 'Y',
#    'diff': 9.82675,
#    'out': 0},
#   {'เลขที่ใบสั่งขาย': 'x35482',
#    'กำหนดส่ง': '7/11/2023',
#    'แผ่นหน้า': 'CM127',
#    'ลอน C': 'CM127',
#    'แผ่นกลาง': 'CM127',
#    'ลอน B': 'CM127',
#    'แผ่นหลัง': 'CM127',
#    'จำนวนชั้น': 5,
#    'ตัดกว้าง': 11.6142,
#    'ตัดยาว': 23.3465,
#    'จำนวนสั่งขาย': 6000,
#    'ประเภททับเส้น': 'Y',
#    'diff': 9.82675,
#    'out': 0},
#   {'เลขที่ใบสั่งขาย': 'x35934',
#    'กำหนดส่ง': '7/11/2023',
#    'แผ่นหน้า': 'CM127',
#    'ลอน C': 'CM127',
#    'แผ่นกลาง': 'CM127',
#    'ลอน B': 'CM127',
#    'แผ่นหลัง': 'CM127',
#    'จำนวนชั้น': 5,
#    'ตัดกว้าง': 11.6142,
#    'ตัดยาว': 23.3465,
#    'จำนวนสั่งขาย': 6000,
#    'ประเภททับเส้น': 'Y',
#    'diff': 9.82675,
#    'out': 0},
#   {'เลขที่ใบสั่งขาย': 'x35936',
#    'กำหนดส่ง': '7/11/2023',
#    'แผ่นหน้า': 'CM127',
#    'ลอน C': 'CM127',
#    'แผ่นกลาง': 'CM127',
#    'ลอน B': 'CM127',
#    'แผ่นหลัง': 'CM127',
#    'จำนวนชั้น': 5,
#    'ตัดกว้าง': 11.6142,
#    'ตัดยาว': 23.3465,
#    'จำนวนสั่งขาย': 4000,
#    'ประเภททับเส้น': 'Y',
#    'diff': 9.82675,
#    'out': 0},
#   {'เลขที่ใบสั่งขาย': 'x36088',
#    'กำหนดส่ง': '7/12/2023',
#    'แผ่นหน้า': 'CM127',
#    'ลอน C': 'CM127',
#    'แผ่นกลาง': 'CM127',
#    'ลอน B': 'CM127',
#    'แผ่นหลัง': 'CM127',
#    'จำนวนชั้น': 5,
#    'ตัดกว้าง': 11.6142,
#    'ตัดยาว': 23.3465,
#    'จำนวนสั่งขาย': 6000,
#    'ประเภททับเส้น': 'Y',
#    'diff': 9.82675,
#    'out': 0},
#   {'เลขที่ใบสั่งขาย': 'x36113',
#    'กำหนดส่ง': '7/13/2023',
#    'แผ่นหน้า': 'CM127',
#    'ลอน C': 'CM127',
#    'แผ่นกลาง': 'CM127',
#    'ลอน B': 'CM127',
#    'แผ่นหลัง': 'CM127',
#    'จำนวนชั้น': 5,
#    'ตัดกว้าง': 11.6142,
#    'ตัดยาว': 23.3465,
#    'จำนวนสั่งขาย': 8000,
#    'ประเภททับเส้น': 'Y',
#    'diff': 9.82675,
#    'out': 0},
#   {'เลขที่ใบสั่งขาย': 'x36327',
#    'กำหนดส่ง': '7/15/2023',
#    'แผ่นหน้า': 'CM127',
#    'ลอน C': 'CM127',
#    'แผ่นกลาง': 'CM127',
#    'ลอน B': 'CM127',
#    'แผ่นหลัง': 'CM127',
#    'จำนวนชั้น': 5,
#    'ตัดกว้าง': 11.6142,
#    'ตัดยาว': 23.3465,
#    'จำนวนสั่งขาย': 7000,
#    'ประเภททับเส้น': 'Y',
#    'diff': 9.82675,
#    'out': 0},
#   {'เลขที่ใบสั่งขาย': 'x36720',
#    'กำหนดส่ง': '7/18/2023',
#    'แผ่นหน้า': 'CM127',
#    'ลอน C': 'CM127',
#    'แผ่นกลาง': 'CM127',
#    'ลอน B': 'CM127',
#    'แผ่นหลัง': 'CM127',
#    'จำนวนชั้น': 5,
#    'ตัดกว้าง': 11.6142,
#    'ตัดยาว': 23.3465,
#    'จำนวนสั่งขาย': 6000,
#    'ประเภททับเส้น': 'Y',
#    'diff': 9.82675,
#    'out': 0},
#   {'เลขที่ใบสั่งขาย': 'x37357',
#    'กำหนดส่ง': '7/21/2023',
#    'แผ่นหน้า': 'CM127',
#    'ลอน C': 'CM127',
#    'แผ่นกลาง': 'CM127',
#    'ลอน B': 'CM127',
#    'แผ่นหลัง': 'CM127',
#    'จำนวนชั้น': 5,
#    'ตัดกว้าง': 11.6142,
#    'ตัดยาว': 23.3465,
#    'จำนวนสั่งขาย': 10000,
#    'ประเภททับเส้น': 'Y',
#    'diff': 9.82675,
#    'out': 0},
#   {'เลขที่ใบสั่งขาย': 'x37401',
#    'กำหนดส่ง': '7/22/2023',
#    'แผ่นหน้า': 'CM127',
#    'ลอน C': 'CM127',
#    'แผ่นกลาง': 'CM127',
#    'ลอน B': 'CM127',
#    'แผ่นหลัง': 'CM127',
#    'จำนวนชั้น': 5,
#    'ตัดกว้าง': 11.6142,
#    'ตัดยาว': 23.3465,
#    'จำนวนสั่งขาย': 8000,
#    'ประเภททับเส้น': 'Y',
#    'diff': 9.82675,
#    'out': 0},
#   {'เลขที่ใบสั่งขาย': 'x37464',
#    'กำหนดส่ง': '7/24/2023',
#    'แผ่นหน้า': 'CM127',
#    'ลอน C': 'CM127',
#    'แผ่นกลาง': 'CM127',
#    'ลอน B': 'CM127',
#    'แผ่นหลัง': 'CM127',
#    'จำนวนชั้น': 5,
#    'ตัดกว้าง': 11.6142,
#    'ตัดยาว': 23.3465,
#    'จำนวนสั่งขาย': 5000,
#    'ประเภททับเส้น': 'Y',
#    'diff': 9.82675,
#    'out': 0},
#   {'เลขที่ใบสั่งขาย': 'x37624',
#    'กำหนดส่ง': '7/25/2023',
#    'แผ่นหน้า': 'CM127',
#    'ลอน C': 'CM127',
#    'แผ่นกลาง': 'CM127',
#    'ลอน B': 'CM127',
#    'แผ่นหลัง': 'CM127',
#    'จำนวนชั้น': 5,
#    'ตัดกว้าง': 11.6142,
#    'ตัดยาว': 23.3465,
#    'จำนวนสั่งขาย': 5000,
#    'ประเภททับเส้น': 'Y',
#    'diff': 9.82675,
#    'out': 0},
#   {'เลขที่ใบสั่งขาย': 'x38090',
#    'กำหนดส่ง': '7/27/2023',
#    'แผ่นหน้า': 'CM127',
#    'ลอน C': 'CM127',
#    'แผ่นกลาง': 'CM127',
#    'ลอน B': 'CM127',
#    'แผ่นหลัง': 'CM127',
#    'จำนวนชั้น': 5,
#    'ตัดกว้าง': 11.6142,
#    'ตัดยาว': 23.3465,
#    'จำนวนสั่งขาย': 8000,
#    'ประเภททับเส้น': 'Y',
#    'diff': 9.82675,
#    'out': 0},
#   {'เลขที่ใบสั่งขาย': 'x38769',
#    'กำหนดส่ง': '8/3/2023',
#    'แผ่นหน้า': 'CM127',
#    'ลอน C': 'CM127',
#    'แผ่นกลาง': 'CM127',
#    'ลอน B': 'CM127',
#    'แผ่นหลัง': 'CM127',
#    'จำนวนชั้น': 5,
#    'ตัดกว้าง': 11.6142,
#    'ตัดยาว': 23.3465,
#    'จำนวนสั่งขาย': 4000,
#    'ประเภททับเส้น': 'Y',
#    'diff': 9.82675,
#    'out': 0},
#   {'เลขที่ใบสั่งขาย': 'x38977',
#    'กำหนดส่ง': '8/4/2023',
#    'แผ่นหน้า': 'CM127',
#    'ลอน C': 'CM127',
#    'แผ่นกลาง': 'CM127',
#    'ลอน B': 'CM127',
#    'แผ่นหลัง': 'CM127',
#    'จำนวนชั้น': 5,
#    'ตัดกว้าง': 11.6142,
#    'ตัดยาว': 23.3465,
#    'จำนวนสั่งขาย': 1370,
#    'ประเภททับเส้น': 'Y',
#    'diff': 9.82675,
#    'out': 0},
#   {'เลขที่ใบสั่งขาย': 'x39515',
#    'กำหนดส่ง': '8/9/2023',
#    'แผ่นหน้า': 'CM127',
#    'ลอน C': 'CM127',
#    'แผ่นกลาง': 'CM127',
#    'ลอน B': 'CM127',
#    'แผ่นหลัง': 'CM127',
#    'จำนวนชั้น': 5,
#    'ตัดกว้าง': 11.6142,
#    'ตัดยาว': 23.3465,
#    'จำนวนสั่งขาย': 5000,
#    'ประเภททับเส้น': 'Y',
#    'diff': 9.82675,
#    'out': 0},
#   {'เลขที่ใบสั่งขาย': 'x39767',
#    'กำหนดส่ง': '8/9/2023',
#    'แผ่นหน้า': 'CM127',
#    'ลอน C': 'CM127',
#    'แผ่นกลาง': 'CM127',
#    'ลอน B': 'CM127',
#    'แผ่นหลัง': 'CM127',
#    'จำนวนชั้น': 5,
#    'ตัดกว้าง': 11.6142,
#    'ตัดยาว': 23.3465,
#    'จำนวนสั่งขาย': 8000,
#    'ประเภททับเส้น': 'Y',
#    'diff': 9.82675,
#    'out': 0},
#   {'เลขที่ใบสั่งขาย': 'x39802',
#    'กำหนดส่ง': '8/10/2023',
#    'แผ่นหน้า': 'CM127',
#    'ลอน C': 'CM127',
#    'แผ่นกลาง': 'CM127',
#    'ลอน B': 'CM127',
#    'แผ่นหลัง': 'CM127',
#    'จำนวนชั้น': 5,
#    'ตัดกว้าง': 11.6142,
#    'ตัดยาว': 23.3465,
#    'จำนวนสั่งขาย': 5000,
#    'ประเภททับเส้น': 'Y',
#    'diff': 9.82675,
#    'out': 0},
#   {'เลขที่ใบสั่งขาย': 'x39995',
#    'กำหนดส่ง': '8/14/2023',
#    'แผ่นหน้า': 'CM127',
#    'ลอน C': 'CM127',
#    'แผ่นกลาง': 'CM127',
#    'ลอน B': 'CM127',
#    'แผ่นหลัง': 'CM127',
#    'จำนวนชั้น': 5,
#    'ตัดกว้าง': 11.6142,
#    'ตัดยาว': 23.3465,
#    'จำนวนสั่งขาย': 5000,
#    'ประเภททับเส้น': 'Y',
#    'diff': 9.82675,
#    'out': 0},
#   {'เลขที่ใบสั่งขาย': 'x40060',
#    'กำหนดส่ง': '8/15/2023',
#    'แผ่นหน้า': 'CM127',
#    'ลอน C': 'CM127',
#    'แผ่นกลาง': 'CM127',
#    'ลอน B': 'CM127',
#    'แผ่นหลัง': 'CM127',
#    'จำนวนชั้น': 5,
#    'ตัดกว้าง': 11.6142,
#    'ตัดยาว': 23.3465,
#    'จำนวนสั่งขาย': 3000,
#    'ประเภททับเส้น': 'Y',
#    'diff': 9.82675,
#    'out': 0}],
#  'trim': np.float64(19.6535)}
