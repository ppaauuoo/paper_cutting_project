# %%
import pandas as pd


data = pd.read_excel('.\media\exports\orders_export_2024-09-09_13-44-04.xlsx', engine="openpyxl")

data.head(5)
# Out:
#    blade_1_orders__id  blade_2_orders__id  \
# 0                 142                   0
# 1                   0                 142
# 2                 143                   0
# 3                 144                   0
# 4                   0                 144
#
#                                             order_id  plan_quantity  out  \
# 0  12181161272-A-027541ef-ecba-4aad-935e-df49a8e8...           1150    2
# 1  12181166049-A-23828672-eccc-401c-819b-e5538e91...           1172    1
# 2  12181158249-E-1a929f6f-fe12-4e2a-aa6f-e914f204...           6800    3
# 3  12181158977-A-75e6e063-535c-40bc-96ce-0ed67e74...            870    1
# 4  12181161069-A-fc2176e8-0c6f-4c6c-87bb-e32c0f75...           1676    2
#
#   blade_type  paper_roll  order_leftover  \
# 0    Blade 1          79            2300
# 1    Blade 2          79            4328
# 2    Blade 1          68           20400
# 3    Blade 1          66             870
# 4    Blade 2          66             224
#
# ...

# %%
data.duplicated(subset=['id'],keep=False)
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10     True
# 11    False
# 12     True
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26     True
# 27    False
# 28     True
# 29    False
# 30     True
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44     True
# 45    False
# 46    False
# 47    False
# 48    False
# dtype: bool

# %%
data
# Out:
#     blade_1_orders__id  blade_2_orders__id  \
# 0                  142                   0
# 1                    0                 142
# 2                  143                   0
# 3                  144                   0
# 4                    0                 144
# 5                  145                   0
# 6                    0                 145
# 7                  146                   0
# 8                    0                 146
# 9                  147                   0
# 10                   0                 147
# 11                 148                   0
# 12                   0                 148
# 13                 149                   0
# 14                   0                 149
# 15                 150                   0
# 16                   0                 150
# 17                 151                   0
# 18                   0                 151
# 19                 152                   0
# 20                   0                 152
# ...
